# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None
# top_10_most_dense_Countries = df[df.P_density >= 100].sort_values(by='P_density', ascending=False).head(10)

# %%
df = pd.read_csv('archive/world-data-2023.csv')

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
# 2            Algiers       150,006  151.36          2.00%           DZD
# 3   Andorra la Vella           469     NaN            NaN           EUR
# 4             Luanda        34,693  261.73         17.10%           AOA
#
#    Fertility Rate Forested Area (%) Gasoline Price                GDP  \
# 0            4.47             2.10%         $0.70    $19,101,353,833
# 1            1.62            28.10%         $1.36    $15,278,077,447
# 2            3.02             0.80%         $0.28   $169,988,236,398
# 3            1.27            34.00%         $1.51     $3,154,057,987
# 4            5.52            46.30%         $0.97    $94,635,415,870
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
# 2                                109.90%
# 3                                106.40%
# 4                                113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887

# %%
df.tail()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 190  Venezuela               32           VE                24.50%
# 191    Vietnam              314           VN                39.30%
# 192      Yemen               56           YE                44.60%
# 193     Zambia               25           ZM                32.10%
# 194   Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 190        912,050           343,000       17.88          58.0
# 191        331,210           522,000       16.75          84.0
# 192        527,968            40,000       30.45         967.0
# 193        752,618            16,000       36.19         260.0
# 194        390,757            51,000       30.68         263.0
#
#     Capital/Major City Co2-Emissions       CPI CPI Change (%) Currency-Code  \
# 190            Caracas       164,175  2,740.27        254.90%           VED
# 191              Hanoi       192,668    163.52          2.80%           VND
# 192              Sanaa        10,609    157.58          8.10%           YER
# 193             Lusaka         5,141    212.31          9.20%           ZMW
# 194             Harare        10,983    105.51          0.90%           NaN
#
#      Fertility Rate Forested Area (%) Gasoline Price                GDP  \
# 190            2.27            52.70%         $0.00   $482,359,318,768
# 191            2.05            48.10%         $0.80   $261,921,244,843
# 192            3.79             1.00%         $0.92    $26,914,402,224
# 193            4.63            65.20%         $1.40    $23,064,722,446
# 194            3.62            35.50%         $1.34    $21,440,758,800
#
#     Gross primary education enrollment (%)  \
# 190                                 97.20%
# 191                                110.60%
# 192                                 93.60%
# 193                                 98.70%
# 194                                109.90%
#
#     Gross tertiary education enrollment (%)  Infant mortality  \
# 190                                  79.30%              21.4
# 191                                  28.50%              16.5
# 192                                  10.20%              42.9
# 193                                   4.10%              40.4
# 194                                  10.00%              33.9
#
#          Largest city  Life expectancy  Maternal mortality ratio Minimum wage  \
# 190           Caracas             72.1                     125.0       $0.01
# 191  Ho Chi Minh City             75.3                      43.0       $0.73
# 192             Sanaa             66.1                     164.0          NaN
# 193            Lusaka             63.5                     213.0       $0.24
# 194            Harare             61.2                     458.0          NaN
#
#     Official language Out of pocket health expenditure  \
# 190           Spanish                           45.80%
# 191        Vietnamese                           43.50%
# 192            Arabic                           81.00%
# 193           English                           27.50%
# 194             Shona                           25.80%
#
#      Physicians per thousand  Population  \
# 190                     1.92  28,515,829
# 191                     0.82  96,462,106
# 192                     0.31  29,161,922
# 193                     1.19  17,861,030
# 194                     0.21  14,645,468
#
#     Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 190                                    59.70%             NaN         73.30%
# 191                                    77.40%          19.10%         37.60%
# 192                                    38.00%             NaN         26.60%
# 193                                    74.60%          16.20%         15.60%
# 194                                    83.10%          20.70%         31.60%
#
#     Unemployment rate Urban_population   Latitude   Longitude
# 190             8.80%       25,162,368   6.423750  -66.589730
# 191             2.01%       35,332,140  14.058324  108.277199
# 192            12.91%       10,869,523  15.552727   48.516388
# 193            11.43%        7,871,713 -13.133897   27.849332
# 194             4.95%        4,717,305 -19.015438   29.154857

# %%
df.shape
# Out:
# (195, 35)

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
df.rename({'Density\n(P/Km2)':'P_density', 'Co2-Emissions':'Co2_Emissions'}, axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country P_density Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 0  Afghanistan        60           AF                58.10%        652,230
# 1      Albania       105           AL                43.10%         28,748
# 2      Algeria        18           DZ                17.40%      2,381,741
# 3      Andorra       164           AD                40.00%            468
# 4       Angola        26           AO                47.50%      1,246,700
#
#   Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0           323,000       32.49          93.0              Kabul
# 1             9,000       11.78         355.0             Tirana
# 2           317,000       24.28         213.0            Algiers
# 3               NaN        7.20         376.0   Andorra la Vella
# 4           117,000       40.73         244.0             Luanda
#
#   Co2_Emissions     CPI CPI Change (%) Currency-Code  Fertility Rate  \
# 0         8,672   149.9          2.30%           AFN            4.47
# 1         4,536  119.05          1.40%           ALL            1.62
# 2       150,006  151.36          2.00%           DZD            3.02
# 3           469     NaN            NaN           EUR            1.27
# 4        34,693  261.73         17.10%           AOA            5.52
#
#   Forested Area (%) Gasoline Price                GDP  \
# 0             2.10%         $0.70    $19,101,353,833
# 1            28.10%         $1.36    $15,278,077,447
# 2             0.80%         $0.28   $169,988,236,398
# 3            34.00%         $1.51     $3,154,057,987
# 4            46.30%         $0.97    $94,635,415,870
#
#   Gross primary education enrollment (%)  \
# 0                                104.00%
# 1                                107.00%
# 2                                109.90%
# 3                                106.40%
# 4                                113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
# 2                           28.10%                     1.72  43,053,054
# 3                           36.40%                     3.33      77,142
# 4                           33.40%                     0.21  31,825,295
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
# 2                                    41.20%          37.20%         66.10%
# 3                                       NaN             NaN            NaN
# 4                                    77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   P_density                                  195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2_Emissions                              188 non-null    object
#  10  CPI                                        178 non-null    object
#  11  CPI Change (%)                             179 non-null    object
#  12  Currency-Code                              180 non-null    object
#  13  Fertility Rate                             188 non-null    float64
#  14  Forested Area (%)                          188 non-null    object
#  15  Gasoline Price                             175 non-null    object
#  16  GDP                                        193 non-null    object
#  17  Gross primary education enrollment (%)     188 non-null    object
#  18  Gross tertiary education enrollment (%)    183 non-null    object
#  19  Infant mortality                           189 non-null    float64
#  20  Largest city                               189 non-null    object
#  21  Life expectancy                            187 non-null    float64
#  22  Maternal mortality ratio                   181 non-null    float64
#  23  Minimum wage                               150 non-null    object
#  24  Official language                          190 non-null    object
#  25  Out of pocket health expenditure           188 non-null    object
#  26  Physicians per thousand                    188 non-null    float64
#  27  Population                                 194 non-null    object
#  28  Population: Labor force participation (%)  176 non-null    object
#  29  Tax revenue (%)                            169 non-null    object
#  30  Total tax rate                             183 non-null    object
#  31  Unemployment rate                          176 non-null    object
#  32  Urban_population                           190 non-null    object
#  33  Latitude                                   194 non-null    float64
#  34  Longitude                                  194 non-null    float64
# dtypes: float64(9), object(26)
# memory usage: 53.4+ KB

# %%
df.describe()
# Out:
#        Birth Rate  Calling Code  Fertility Rate  Infant mortality  \
# count  189.000000    194.000000      188.000000        189.000000
# mean    20.214974    360.546392        2.698138         21.332804
# std      9.945774    323.236419        1.282267         19.548058
# min      5.900000      1.000000        0.980000          1.400000
# 25%     11.300000     82.500000        1.705000          6.000000
# 50%     17.950000    255.500000        2.245000         14.000000
# 75%     28.750000    506.750000        3.597500         32.700000
# max     46.080000   1876.000000        6.910000         84.500000
#
#        Life expectancy  Maternal mortality ratio  Physicians per thousand  \
# count       187.000000                181.000000               188.000000
# mean         72.279679                160.392265                 1.839840
# std           7.483661                233.502024                 1.684261
# min          52.800000                  2.000000                 0.010000
# 25%          67.000000                 13.000000                 0.332500
# 50%          73.200000                 53.000000                 1.460000
# 75%          77.500000                186.000000                 2.935000
# max          85.400000               1150.000000                 8.420000
#
#          Latitude   Longitude
# count  194.000000  194.000000
# mean    19.092351   20.232434
# std     23.961779   66.716110
# min    -40.900557 -175.198242
# 25%      4.544175   -7.941496
# 50%     17.273849   20.972652
# 75%     40.124603   48.281523
# max     64.963051  178.065032

# %%
df.columns
# Out:
# Index(['Country', 'P_density', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2_Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
columns_to_convert = ['P_density', 'Agricultural Land( %)', 'Land Area(Km2)',
                      'Birth Rate', 'Co2_Emissions', 'Forested Area (%)',
                      'CPI', 'CPI Change (%)', 'Fertility Rate', 'Gasoline Price', 'GDP',
                      'Gross primary education enrollment (%)', 'Armed Forces size',
                      'Gross tertiary education enrollment (%)', 'Infant mortality',
                      'Life expectancy', 'Maternal mortality ratio', 'Minimum wage', 
                      'Out of pocket health expenditure', 'Physicians per thousand', 
                      'Population', 'Population: Labor force participation (%)', 
                      'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 'Urban_population']

# Convert columns using a lambda function
df[columns_to_convert] = df[columns_to_convert].map(lambda x: float(str(x).replace(',', '').replace('$', '').replace('%', '')))

# %% [markdown]
# ## handling Missing Values

# %%
df.head()
# Out:
#        Country  P_density Abbreviation  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan       60.0           AF                   58.1        652230.0
# 1      Albania      105.0           AL                   43.1         28748.0
# 2      Algeria       18.0           DZ                   17.4       2381741.0
# 3      Andorra      164.0           AD                   40.0           468.0
# 4       Angola       26.0           AO                   47.5       1246700.0
#
#    Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0           323000.0       32.49          93.0              Kabul
# 1             9000.0       11.78         355.0             Tirana
# 2           317000.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4           117000.0       40.73         244.0             Luanda
#
#    Co2_Emissions     CPI  CPI Change (%) Currency-Code  Fertility Rate  \
# 0         8672.0  149.90             2.3           AFN            4.47
# 1         4536.0  119.05             1.4           ALL            1.62
# 2       150006.0  151.36             2.0           DZD            3.02
# 3          469.0     NaN             NaN           EUR            1.27
# 4        34693.0  261.73            17.1           AOA            5.52
#
#    Forested Area (%)  Gasoline Price           GDP  \
# 0                2.1            0.70  1.910135e+10
# 1               28.1            1.36  1.527808e+10
# 2                0.8            0.28  1.699882e+11
# 3               34.0            1.51  3.154058e+09
# 4               46.3            0.97  9.463542e+10
#
#    Gross primary education enrollment (%)  \
# 0                                   104.0
# 1                                   107.0
# 2                                   109.9
# 3                                   106.4
# 4                                   113.5
#
#    Gross tertiary education enrollment (%)  Infant mortality  \
# 0                                      9.7              47.9
# 1                                     55.0               7.8
# 2                                     51.4              20.1
# 3                                      NaN               2.7
# 4                                      9.3              51.6
#
#        Largest city  Life expectancy  Maternal mortality ratio  Minimum wage  \
# 0             Kabul             64.5                     638.0          0.43
# 1            Tirana             78.5                      15.0          1.12
# 2           Algiers             76.7                     112.0          0.95
# 3  Andorra la Vella              NaN                       NaN          6.63
# 4            Luanda             60.8                     241.0          0.71
#
#   Official language  Out of pocket health expenditure  \
# 0            Pashto                              78.4
# 1          Albanian                              56.9
# 2            Arabic                              28.1
# 3           Catalan                              36.4
# 4        Portuguese                              33.4
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     3.33     77142.0
# 4                     0.21  31825295.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                       48.9              9.3            71.4
# 1                                       55.7             18.6            36.6
# 2                                       41.2             37.2            66.1
# 3                                        NaN              NaN             NaN
# 4                                       77.5              9.2            49.1
#
#    Unemployment rate  Urban_population   Latitude  Longitude
# 0              11.12         9797273.0  33.939110  67.709953
# 1              12.33         1747593.0  41.153332  20.168331
# 2              11.70        31510100.0  28.033886   1.659626
# 3                NaN           67873.0  42.506285   1.521801
# 4               6.89        21061025.0 -11.202692  17.873887

# %%
df.isnull().sum()
# Out:
# Country                                       0
# P_density                                     0
# Abbreviation                                  7
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2_Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Largest city                                  6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# Official language                             5
# Out of pocket health expenditure              7
# Physicians per thousand                       7
# Population                                    1
# Population: Labor force participation (%)    19
# Tax revenue (%)                              26
# Total tax rate                               12
# Unemployment rate                            19
# Urban_population                              5
# Latitude                                      1
# Longitude                                     1
# dtype: int64

# %% [markdown]
# ### Fixing Abbreviration Col

# %%
df[df.Abbreviation.isnull()]
# Out:
#                             Country  P_density Abbreviation  \
# 39            Republic of the Congo       16.0          NaN
# 56                         Eswatini       67.0          NaN
# 73                     Vatican City     2003.0          NaN
# 81              Republic of Ireland       72.0          NaN
# 119                         Namibia        3.0          NaN
# 128                 North Macedonia       83.0          NaN
# 133  Palestinian National Authority      847.0          NaN
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 39                    31.1        342000.0            12000.0       32.86
# 56                     NaN         17364.0                NaN         NaN
# 73                     NaN             0.0                NaN         NaN
# 81                    64.5         70273.0             9000.0       12.50
# 119                   47.1        824292.0            16000.0       28.64
# 128                    NaN         25713.0                NaN         NaN
# 133                    NaN             NaN                NaN         NaN
#
#      Calling Code Capital/Major City  Co2_Emissions     CPI  CPI Change (%)  \
# 39          242.0        Brazzaville         3282.0  124.74             2.2
# 56          268.0            Mbabane            NaN     NaN             NaN
# 73          379.0       Vatican City            NaN     NaN             NaN
# 81          353.0             Dublin        37711.0  106.58             0.9
# 119         264.0           Windhoek         4228.0  157.97             3.7
# 128         389.0             Skopje            NaN     NaN             NaN
# 133           NaN                NaN            NaN     NaN             NaN
#
#     Currency-Code  Fertility Rate  Forested Area (%)  Gasoline Price  \
# 39            XAF            4.43               65.4            0.97
# 56            NaN             NaN                NaN             NaN
# 73            EUR             NaN                NaN             NaN
# 81            EUR            1.75               11.0            1.37
# 119           NaN            3.40                8.3            0.76
# 128           MKD             NaN                NaN             NaN
# 133           NaN             NaN                NaN             NaN
#
#               GDP  Gross primary education enrollment (%)  \
# 39   1.082059e+10                                   106.6
# 56   3.791304e+09                                     NaN
# 73            NaN                                     NaN
# 81   3.886987e+11                                   100.9
# 119  1.236653e+10                                   124.2
# 128  1.022078e+10                                     NaN
# 133           NaN                                     NaN
#
#      Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 39                                      12.7              36.2  Brazzaville
# 56                                       NaN               NaN      Mbabane
# 73                                       NaN               NaN          NaN
# 81                                      77.8               3.1     Connacht
# 119                                     22.9              29.0     Windhoek
# 128                                      NaN               NaN       Skopje
# 133                                      NaN               NaN          NaN
#
#      Life expectancy  Maternal mortality ratio  Minimum wage  \
# 39              64.3                     378.0          0.88
# 56               NaN                       NaN           NaN
# 73               NaN                       NaN           NaN
# 81              82.3                       5.0         10.79
# 119             63.4                     195.0           NaN
# 128              NaN                       NaN           NaN
# 133              NaN                       NaN           NaN
#
#     Official language  Out of pocket health expenditure  \
# 39             French                              43.8
# 56            English                              11.3
# 73            Italian                               NaN
# 81              Irish                              15.2
# 119           English                               8.3
# 128        Macedonian                              35.6
# 133            Arabic                               NaN
#
#      Physicians per thousand  Population  \
# 39                      0.12   5380508.0
# 56                       NaN   1093238.0
# 73                       NaN       836.0
# 81                      3.31   5007069.0
# 119                     0.42   2494530.0
# 128                      NaN   1836713.0
# 133                      NaN         NaN
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 39                                        69.4              9.0
# 56                                         NaN             28.6
# 73                                         NaN              NaN
# 81                                        62.1             18.3
# 119                                       59.5             27.1
# 128                                        NaN              NaN
# 133                                        NaN              NaN
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  Longitude
# 39             54.3               9.47         3625010.0  -0.228021  15.827659
# 56              NaN                NaN               NaN -26.522503  31.465866
# 73              NaN                NaN               NaN  41.902916  12.453389
# 81             26.1               4.93         3133123.0  53.412910  -8.243890
# 119            20.7              20.27         1273258.0 -22.957640  18.490410
# 128             NaN                NaN               NaN  41.608635  21.745275
# 133             NaN                NaN               NaN  31.952162  35.233154

# %%
col = 2
NaN_Abbr_row = [39, 56, 73, 81, 119, 128, 133]
corresponding_Abbr = ['CG','SZ','VA','IE','NA','MK','PS']

for i in range(len(NaN_Abbr_row)):
    df.iloc[NaN_Abbr_row[i],col] = corresponding_Abbr[i]

# %%
df.isnull().sum()
# Out:
# Country                                       0
# P_density                                     0
# Abbreviation                                  0
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2_Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Largest city                                  6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# Official language                             5
# Out of pocket health expenditure              7
# Physicians per thousand                       7
# Population                                    1
# Population: Labor force participation (%)    19
# Tax revenue (%)                              26
# Total tax rate                               12
# Unemployment rate                            19
# Urban_population                              5
# Latitude                                      1
# Longitude                                     1
# dtype: int64

# %% [markdown]
# ### Fixing Agricultural Land( %) col

# %%
df['Agricultural Land( %)'].describe()
# Out:
# count    188.000000
# mean      39.117553
# std       21.783052
# min        0.600000
# 25%       21.700000
# 50%       39.600000
# 75%       55.375000
# max       82.600000
# Name: Agricultural Land( %), dtype: float64

# %%
df['Agricultural Land( %)'] = df['Agricultural Land( %)'].fillna(df['Agricultural Land( %)'].mean())

# %%
df
# Out:
#          Country  P_density Abbreviation  Agricultural Land( %)  \
# 0    Afghanistan       60.0           AF                   58.1
# 1        Albania      105.0           AL                   43.1
# 2        Algeria       18.0           DZ                   17.4
# 3        Andorra      164.0           AD                   40.0
# 4         Angola       26.0           AO                   47.5
# ..           ...        ...          ...                    ...
# 190    Venezuela       32.0           VE                   24.5
# 191      Vietnam      314.0           VN                   39.3
# 192        Yemen       56.0           YE                   44.6
# 193       Zambia       25.0           ZM                   32.1
# 194     Zimbabwe       38.0           ZW                   41.9
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0          652230.0           323000.0       32.49          93.0
# 1           28748.0             9000.0       11.78         355.0
# 2         2381741.0           317000.0       24.28         213.0
# 3             468.0                NaN        7.20         376.0
# 4         1246700.0           117000.0       40.73         244.0
# ..              ...                ...         ...           ...
# 190        912050.0           343000.0       17.88          58.0
# 191        331210.0           522000.0       16.75          84.0
# 192        527968.0            40000.0       30.45         967.0
# 193        752618.0            16000.0       36.19         260.0
# 194        390757.0            51000.0       30.68         263.0
#
#     Capital/Major City  Co2_Emissions      CPI  CPI Change (%) Currency-Code  \
# 0                Kabul         8672.0   149.90             2.3           AFN
# 1               Tirana         4536.0   119.05             1.4           ALL
# 2              Algiers       150006.0   151.36             2.0           DZD
# 3     Andorra la Vella          469.0      NaN             NaN           EUR
# 4               Luanda        34693.0   261.73            17.1           AOA
# ..                 ...            ...      ...             ...           ...
# 190            Caracas       164175.0  2740.27           254.9           VED
# 191              Hanoi       192668.0   163.52             2.8           VND
# 192              Sanaa        10609.0   157.58             8.1           YER
# 193             Lusaka         5141.0   212.31             9.2           ZMW
# 194             Harare        10983.0   105.51             0.9           NaN
#
#      Fertility Rate  Forested Area (%)  Gasoline Price           GDP  \
# 0              4.47                2.1            0.70  1.910135e+10
# 1              1.62               28.1            1.36  1.527808e+10
# 2              3.02                0.8            0.28  1.699882e+11
# 3              1.27               34.0            1.51  3.154058e+09
# 4              5.52               46.3            0.97  9.463542e+10
# ..              ...                ...             ...           ...
# 190            2.27               52.7            0.00  4.823593e+11
# 191            2.05               48.1            0.80  2.619212e+11
# 192            3.79                1.0            0.92  2.691440e+10
# 193            4.63               65.2            1.40  2.306472e+10
# 194            3.62               35.5            1.34  2.144076e+10
#
#      Gross primary education enrollment (%)  \
# 0                                     104.0
# 1                                     107.0
# 2                                     109.9
# 3                                     106.4
# 4                                     113.5
# ..                                      ...
# 190                                    97.2
# 191                                   110.6
# 192                                    93.6
# 193                                    98.7
# 194                                   109.9
#
#      Gross tertiary education enrollment (%)  Infant mortality  \
# 0                                        9.7              47.9
# 1                                       55.0               7.8
# 2                                       51.4              20.1
# 3                                        NaN               2.7
# 4                                        9.3              51.6
# ..                                       ...               ...
# 190                                     79.3              21.4
# 191                                     28.5              16.5
# 192                                     10.2              42.9
# 193                                      4.1              40.4
# 194                                     10.0              33.9
#
#          Largest city  Life expectancy  Maternal mortality ratio  \
# 0               Kabul             64.5                     638.0
# 1              Tirana             78.5                      15.0
# 2             Algiers             76.7                     112.0
# 3    Andorra la Vella              NaN                       NaN
# 4              Luanda             60.8                     241.0
# ..                ...              ...                       ...
# 190           Caracas             72.1                     125.0
# 191  Ho Chi Minh City             75.3                      43.0
# 192             Sanaa             66.1                     164.0
# 193            Lusaka             63.5                     213.0
# 194            Harare             61.2                     458.0
#
#      Minimum wage Official language  Out of pocket health expenditure  \
# 0            0.43            Pashto                              78.4
# 1            1.12          Albanian                              56.9
# 2            0.95            Arabic                              28.1
# 3            6.63           Catalan                              36.4
# 4            0.71        Portuguese                              33.4
# ..            ...               ...                               ...
# 190          0.01           Spanish                              45.8
# 191          0.73        Vietnamese                              43.5
# 192           NaN            Arabic                              81.0
# 193          0.24           English                              27.5
# 194           NaN             Shona                              25.8
#
#      Physicians per thousand  Population  \
# 0                       0.28  38041754.0
# 1                       1.20   2854191.0
# 2                       1.72  43053054.0
# 3                       3.33     77142.0
# 4                       0.21  31825295.0
# ..                       ...         ...
# 190                     1.92  28515829.0
# 191                     0.82  96462106.0
# 192                     0.31  29161922.0
# 193                     1.19  17861030.0
# 194                     0.21  14645468.0
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 0                                         48.9              9.3
# 1                                         55.7             18.6
# 2                                         41.2             37.2
# 3                                          NaN              NaN
# 4                                         77.5              9.2
# ..                                         ...              ...
# 190                                       59.7              NaN
# 191                                       77.4             19.1
# 192                                       38.0              NaN
# 193                                       74.6             16.2
# 194                                       83.1             20.7
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  \
# 0              71.4              11.12         9797273.0  33.939110
# 1              36.6              12.33         1747593.0  41.153332
# 2              66.1              11.70        31510100.0  28.033886
# 3               NaN                NaN           67873.0  42.506285
# 4              49.1               6.89        21061025.0 -11.202692
# ..              ...                ...               ...        ...
# 190            73.3               8.80        25162368.0   6.423750
# 191            37.6               2.01        35332140.0  14.058324
# 192            26.6              12.91        10869523.0  15.552727
# 193            15.6              11.43         7871713.0 -13.133897
# 194            31.6               4.95         4717305.0 -19.015438
#
#       Longitude
# 0     67.709953
# 1     20.168331
# 2      1.659626
# 3      1.521801
# 4     17.873887
# ..          ...
# 190  -66.589730
# 191  108.277199
# 192   48.516388
# 193   27.849332
# 194   29.154857
#
# [195 rows x 35 columns]

# %%
df.isnull().sum()
# Out:
# Country                                       0
# P_density                                     0
# Abbreviation                                  0
# Agricultural Land( %)                         0
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2_Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# Largest city                                  6
# Life expectancy                               8
# Maternal mortality ratio                     14
# Minimum wage                                 45
# Official language                             5
# Out of pocket health expenditure              7
# Physicians per thousand                       7
# Population                                    1
# Population: Labor force participation (%)    19
# Tax revenue (%)                              26
# Total tax rate                               12
# Unemployment rate                            19
# Urban_population                              5
# Latitude                                      1
# Longitude                                     1
# dtype: int64

# %%
df[df['Land Area(Km2)'].isnull()]
# Out:
#                             Country  P_density Abbreviation  \
# 133  Palestinian National Authority      847.0           PS
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 133              39.117553             NaN                NaN         NaN
#
#      Calling Code Capital/Major City  Co2_Emissions  CPI  CPI Change (%)  \
# 133           NaN                NaN            NaN  NaN             NaN
#
#     Currency-Code  Fertility Rate  Forested Area (%)  Gasoline Price  GDP  \
# 133           NaN             NaN                NaN             NaN  NaN
#
#      Gross primary education enrollment (%)  \
# 133                                     NaN
#
#      Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 133                                      NaN               NaN          NaN
#
#      Life expectancy  Maternal mortality ratio  Minimum wage  \
# 133              NaN                       NaN           NaN
#
#     Official language  Out of pocket health expenditure  \
# 133            Arabic                               NaN
#
#      Physicians per thousand  Population  \
# 133                      NaN         NaN
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 133                                        NaN              NaN
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  Longitude
# 133             NaN                NaN               NaN  31.952162  35.233154

# %%
df.loc[133,'Land Area(Km2)'] = 6020

# %%
df[df.Abbreviation == 'PS']
# Out:
#                             Country  P_density Abbreviation  \
# 133  Palestinian National Authority      847.0           PS
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 133              39.117553          6020.0                NaN         NaN
#
#      Calling Code Capital/Major City  Co2_Emissions  CPI  CPI Change (%)  \
# 133           NaN                NaN            NaN  NaN             NaN
#
#     Currency-Code  Fertility Rate  Forested Area (%)  Gasoline Price  GDP  \
# 133           NaN             NaN                NaN             NaN  NaN
#
#      Gross primary education enrollment (%)  \
# 133                                     NaN
#
#      Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 133                                      NaN               NaN          NaN
#
#      Life expectancy  Maternal mortality ratio  Minimum wage  \
# 133              NaN                       NaN           NaN
#
#     Official language  Out of pocket health expenditure  \
# 133            Arabic                               NaN
#
#      Physicians per thousand  Population  \
# 133                      NaN         NaN
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 133                                        NaN              NaN
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  Longitude
# 133             NaN                NaN               NaN  31.952162  35.233154

# %% [markdown]
# ### doing one by one is soo time consuming, so lets automate the process

# %%
columns_with_nan = df.isnull().any()
df.columns[columns_with_nan] # returned true values
# Out:
# Index(['Armed Forces size', 'Birth Rate', 'Calling Code', 'Capital/Major City',
#        'Co2_Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code',
#        'Fertility Rate', 'Forested Area (%)', 'Gasoline Price', 'GDP',
#        'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# Imputing Numerical features with Mean
numerical_features = df.select_dtypes(include='float64')
numerical_features = numerical_features.columns[numerical_features.isnull().any()]
numerical_features # nan numerical features
# Out:
# Index(['Armed Forces size', 'Birth Rate', 'Calling Code', 'Co2_Emissions',
#        'CPI', 'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Life expectancy', 'Maternal mortality ratio', 'Minimum wage',
#        'Out of pocket health expenditure', 'Physicians per thousand',
#        'Population', 'Population: Labor force participation (%)',
#        'Tax revenue (%)', 'Total tax rate', 'Unemployment rate',
#        'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df[numerical_features] = df[numerical_features].fillna(df[numerical_features].mean())

# %%
# Imputing Categorial features with Mode
categorical_features = df.select_dtypes(include='object')
categorical_features = categorical_features.columns[categorical_features.isnull().any()]
categorical_features
# Out:
# Index(['Capital/Major City', 'Currency-Code', 'Largest city',
#        'Official language'],
#       dtype='object')

# %%
df[categorical_features] = df[categorical_features].fillna(df[categorical_features].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Country                                      0
# P_density                                    0
# Abbreviation                                 0
# Agricultural Land( %)                        0
# Land Area(Km2)                               0
# Armed Forces size                            0
# Birth Rate                                   0
# Calling Code                                 0
# Capital/Major City                           0
# Co2_Emissions                                0
# CPI                                          0
# CPI Change (%)                               0
# Currency-Code                                0
# Fertility Rate                               0
# Forested Area (%)                            0
# Gasoline Price                               0
# GDP                                          0
# Gross primary education enrollment (%)       0
# Gross tertiary education enrollment (%)      0
# Infant mortality                             0
# Largest city                                 0
# Life expectancy                              0
# Maternal mortality ratio                     0
# Minimum wage                                 0
# Official language                            0
# Out of pocket health expenditure             0
# Physicians per thousand                      0
# Population                                   0
# Population: Labor force participation (%)    0
# Tax revenue (%)                              0
# Total tax rate                               0
# Unemployment rate                            0
# Urban_population                             0
# Latitude                                     0
# Longitude                                    0
# dtype: int64

# %%
df[df.index == 133]
# Out:
#                             Country  P_density Abbreviation  \
# 133  Palestinian National Authority      847.0           PS
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 133              39.117553          6020.0      159274.853801   20.214974
#
#      Calling Code Capital/Major City  Co2_Emissions         CPI  \
# 133    360.546392          Abu Dhabi  177799.239362  190.460955
#
#      CPI Change (%) Currency-Code  Fertility Rate  Forested Area (%)  \
# 133        6.722346           EUR        2.698138          32.015426
#
#      Gasoline Price           GDP  Gross primary education enrollment (%)  \
# 133        1.002457  4.772959e+11                              102.470213
#
#      Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 133                                37.963388         21.332804        S����
#
#      Life expectancy  Maternal mortality ratio  Minimum wage  \
# 133        72.279679                160.392265      2.194133
#
#     Official language  Out of pocket health expenditure  \
# 133            Arabic                         32.637234
#
#      Physicians per thousand    Population  \
# 133                  1.83984  3.938116e+07
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 133                                  62.738068        16.573964
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  Longitude
# 133       40.822404           6.886364      2.230454e+07  31.952162  35.233154

# %%
df[categorical_features].mode()
# Out:
#   Capital/Major City Currency-Code Largest city Official language
# 0          Abu Dhabi           EUR        S����           English

# %% [markdown]
# ## Remove unnecessary special characters

# %%
df['Capital/Major City'] = df['Capital/Major City'].str.replace(r'[^a-zA-Z0-9\s]',"",regex=True)
df['Currency-Code'] = df['Currency-Code'].str.replace(r'[^a-zA-Z0-9\s]',"",regex=True)
df['Largest city'] = df['Largest city'].str.replace(r'[^a-zA-Z0-9\s]',"",regex=True)
df['Official language'] = df['Official language'].str.replace(r'[^a-zA-Z0-9\s]',"",regex=True)

# %%
df[categorical_features].mode()
# Out:
#   Capital/Major City Currency-Code Largest city Official language
# 0          Abu Dhabi           EUR            S           English

# %%
df.head()
# Out:
#        Country  P_density Abbreviation  Agricultural Land( %)  Land Area(Km2)  \
# 0  Afghanistan       60.0           AF                   58.1        652230.0
# 1      Albania      105.0           AL                   43.1         28748.0
# 2      Algeria       18.0           DZ                   17.4       2381741.0
# 3      Andorra      164.0           AD                   40.0           468.0
# 4       Angola       26.0           AO                   47.5       1246700.0
#
#    Armed Forces size  Birth Rate  Calling Code Capital/Major City  \
# 0      323000.000000       32.49          93.0              Kabul
# 1        9000.000000       11.78         355.0             Tirana
# 2      317000.000000       24.28         213.0            Algiers
# 3      159274.853801        7.20         376.0   Andorra la Vella
# 4      117000.000000       40.73         244.0             Luanda
#
#    Co2_Emissions         CPI  CPI Change (%) Currency-Code  Fertility Rate  \
# 0         8672.0  149.900000        2.300000           AFN            4.47
# 1         4536.0  119.050000        1.400000           ALL            1.62
# 2       150006.0  151.360000        2.000000           DZD            3.02
# 3          469.0  190.460955        6.722346           EUR            1.27
# 4        34693.0  261.730000       17.100000           AOA            5.52
#
#    Forested Area (%)  Gasoline Price           GDP  \
# 0                2.1            0.70  1.910135e+10
# 1               28.1            1.36  1.527808e+10
# 2                0.8            0.28  1.699882e+11
# 3               34.0            1.51  3.154058e+09
# 4               46.3            0.97  9.463542e+10
#
#    Gross primary education enrollment (%)  \
# 0                                   104.0
# 1                                   107.0
# 2                                   109.9
# 3                                   106.4
# 4                                   113.5
#
#    Gross tertiary education enrollment (%)  Infant mortality  \
# 0                                 9.700000              47.9
# 1                                55.000000               7.8
# 2                                51.400000              20.1
# 3                                37.963388               2.7
# 4                                 9.300000              51.6
#
#        Largest city  Life expectancy  Maternal mortality ratio  Minimum wage  \
# 0             Kabul        64.500000                638.000000          0.43
# 1            Tirana        78.500000                 15.000000          1.12
# 2           Algiers        76.700000                112.000000          0.95
# 3  Andorra la Vella        72.279679                160.392265          6.63
# 4            Luanda        60.800000                241.000000          0.71
#
#   Official language  Out of pocket health expenditure  \
# 0            Pashto                              78.4
# 1          Albanian                              56.9
# 2            Arabic                              28.1
# 3           Catalan                              36.4
# 4        Portuguese                              33.4
#
#    Physicians per thousand  Population  \
# 0                     0.28  38041754.0
# 1                     1.20   2854191.0
# 2                     1.72  43053054.0
# 3                     3.33     77142.0
# 4                     0.21  31825295.0
#
#    Population: Labor force participation (%)  Tax revenue (%)  Total tax rate  \
# 0                                  48.900000         9.300000       71.400000
# 1                                  55.700000        18.600000       36.600000
# 2                                  41.200000        37.200000       66.100000
# 3                                  62.738068        16.573964       40.822404
# 4                                  77.500000         9.200000       49.100000
#
#    Unemployment rate  Urban_population   Latitude  Longitude
# 0          11.120000         9797273.0  33.939110  67.709953
# 1          12.330000         1747593.0  41.153332  20.168331
# 2          11.700000        31510100.0  28.033886   1.659626
# 3           6.886364           67873.0  42.506285   1.521801
# 4           6.890000        21061025.0 -11.202692  17.873887

# %% [markdown]
# ## Top 20 Highest Populated Countries

# %%
pop_sorted_df  = df.sort_values(by='Population', ascending=False)
top20_populated_countries = pop_sorted_df.head(20)

# %%
# horizontal bar plot
pop_ax = sns.barplot(data=top20_populated_countries, x='Population',y='Country',hue='Country',palette='gist_rainbow_r',saturation=0.7)
for p in pop_ax.patches:
    pop_ax.annotate(f'{p.get_width():,.0f}', (p.get_width(), p.get_y() + p.get_height() / 2),
                     xytext=(5, 0), textcoords='offset points', ha='left', va='center', fontsize=10)

# %% [markdown]
# > As per this 2023 report, India and China are the most populated countries in the world followed by US

# %% [markdown]
# ## Top 20 Most Densed Countries

# %%
dense_sorted_df = df.sort_values(by='P_density', ascending=False)
top20_densed_countries = dense_sorted_df.head(20)

# %%
dense_ax = sns.barplot(data=top20_densed_countries, x='P_density', y='Country', hue='Country',palette='Spectral')
dense_ax.set_title("Top 20 Most Densed Countries")
dense_ax.set_xticklabels(dense_ax.get_xticklabels(), rotation = 45,ha='right')
for p in dense_ax.patches:
    dense_ax.annotate(f'{p.get_width():,.0f}', (p.get_width(), p.get_y() + p.get_height() / 2),
                     xytext=(5, 0), textcoords='offset points', ha='left', va='center', fontsize=10)
plt.show()
# Out:
# C:\Users\GEETURAHULPANCHAL\AppData\Local\Temp\ipykernel_1376\1058828928.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   dense_ax.set_xticklabels(dense_ax.get_xticklabels(), rotation = 45,ha='right')

# %% [markdown]
# > Monaco is the most densely populated country in the world follwed by Singapore.

# %% [markdown]
# ## Top 20 Most Agricultural Land Countries in % Total Land

# %%
agri_sorted_df = df.sort_values(by='Agricultural Land( %)', ascending=False)
top20_most_agri_countries = agri_sorted_df.head(20)

# %%
top20_most_agri_countries['Agricultural Land(Km2)'] = top20_most_agri_countries['Agricultural Land( %)'] / 100 * top20_most_agri_countries['Land Area(Km2)'] 
top20_densed_countries
# Out:
#                             Country  P_density Abbreviation  \
# 113                          Monaco    26337.0           MC
# 156                       Singapore     8358.0           SG
# 12                          Bahrain     2239.0           BH
# 73                     Vatican City     2003.0           VA
# 104                        Maldives     1802.0           MV
# 106                           Malta     1380.0           MT
# 13                       Bangladesh     1265.0           BD
# 133  Palestinian National Authority      847.0           PS
# 111  Federated States of Micronesia      784.0           FM
# 14                         Barbados      668.0           BB
# 94                          Lebanon      667.0           LB
# 109                       Mauritius      626.0           MU
# 149                      San Marino      566.0           SM
# 120                           Nauru      541.0           NR
# 162                     South Korea      527.0           KR
# 144                          Rwanda      525.0           RW
# 122                     Netherlands      508.0           NL
# 38                          Comoros      467.0           KM
# 77                            India      464.0           IN
# 27                          Burundi      463.0           BI
#
#      Agricultural Land( %)  Land Area(Km2)  Armed Forces size  Birth Rate  \
# 113              39.117553             2.0       1.592749e+05    5.900000
# 156               0.900000           716.0       8.100000e+04    8.800000
# 12               11.100000           765.0       1.900000e+04   13.990000
# 73               39.117553             0.0       1.592749e+05   20.214974
# 104              26.300000           298.0       5.000000e+03   14.200000
# 106              32.400000           316.0       2.000000e+03    9.200000
# 13               70.600000        148460.0       2.210000e+05   18.180000
# 133              39.117553          6020.0       1.592749e+05   20.214974
# 111              31.400000           702.0       1.592749e+05   22.820000
# 14               23.300000           430.0       1.000000e+03   10.650000
# 94               64.300000         10400.0       8.000000e+04   17.550000
# 109              42.400000          2040.0       3.000000e+03   10.200000
# 149              16.700000            61.0       1.592749e+05    6.800000
# 120              39.117553            21.0       1.592749e+05   20.214974
# 162              17.400000         99720.0       6.340000e+05    6.400000
# 144              73.400000         26338.0       3.500000e+04   31.700000
# 122              53.300000         41543.0       4.100000e+04    9.700000
# 38               71.500000          2235.0       1.592749e+05   31.880000
# 77               60.400000       3287263.0       3.031000e+06   17.860000
# 27               79.200000         27830.0       3.100000e+04   39.010000
#
#      Calling Code  Capital/Major City  Co2_Emissions         CPI  \
# 113    377.000000         Monaco City   1.777992e+05  190.460955
# 156     65.000000           Abu Dhabi   3.753500e+04  114.410000
# 12     973.000000              Manama   3.169400e+04  117.590000
# 73     379.000000        Vatican City   1.777992e+05  190.460955
# 104    960.000000                 Mal   1.445000e+03   99.700000
# 106    356.000000            Valletta   1.342000e+03  113.450000
# 13     880.000000               Dhaka   8.424600e+04  179.680000
# 133    360.546392           Abu Dhabi   1.777992e+05  190.460955
# 111    691.000000             Palikir   1.430000e+02  112.100000
# 14       1.000000          Bridgetown   1.276000e+03  134.090000
# 94     961.000000              Beirut   2.479600e+04  130.020000
# 109    230.000000          Port Louis   4.349000e+03  129.910000
# 149    378.000000  City of San Marino   1.777992e+05  110.630000
# 120    674.000000      Yaren District   1.777992e+05  190.460955
# 162     82.000000               Seoul   6.203020e+05  115.160000
# 144    250.000000              Kigali   1.115000e+03  151.090000
# 122     31.000000           Amsterdam   1.707800e+05  115.910000
# 38     269.000000      Moroni Comoros   2.020000e+02  103.620000
# 77      91.000000           New Delhi   2.407672e+06  180.440000
# 27     257.000000           Bujumbura   4.950000e+02  182.110000
#
#      CPI Change (%) Currency-Code  Fertility Rate  Forested Area (%)  \
# 113        6.722346           EUR        2.698138          32.015426
# 156        0.600000           SGD        1.140000          23.100000
# 12         2.100000           BHD        1.990000           0.800000
# 73         6.722346           EUR        2.698138          32.015426
# 104        0.200000           EUR        1.870000           3.300000
# 106        1.600000           EUR        1.230000           1.100000
# 13         5.600000           BDT        2.040000          11.000000
# 133        6.722346           EUR        2.698138          32.015426
# 111        0.500000           USD        3.050000          91.900000
# 14         4.100000           BBD        1.620000          14.700000
# 94         3.000000           LBP        2.090000          13.400000
# 109        0.400000           MUR        1.410000          19.000000
# 149        1.000000           EUR        1.260000           0.000000
# 120        6.722346           AUD        2.698138          32.015426
# 162        0.400000           KRW        0.980000          63.400000
# 144        3.400000           RWF        4.040000          19.700000
# 122        2.600000           EUR        1.590000          11.200000
# 38        -4.300000           KMF        4.210000          19.700000
# 77         7.700000           INR        2.220000          23.800000
# 27        -0.700000           BIF        5.410000          10.900000
#
#      Gasoline Price           GDP  Gross primary education enrollment (%)  \
# 113        2.000000  7.184844e+09                              102.470213
# 156        1.250000  3.720625e+11                              100.600000
# 12         0.430000  3.857407e+10                               99.400000
# 73         1.002457  4.772959e+11                              102.470213
# 104        1.630000  5.729248e+09                               97.100000
# 106        1.360000  1.478616e+10                              105.000000
# 13         1.120000  3.025713e+11                              116.500000
# 133        1.002457  4.772959e+11                              102.470213
# 111        1.002457  4.019323e+08                               97.200000
# 14         1.810000  5.209000e+09                               99.400000
# 94         0.740000  5.336704e+10                               95.100000
# 109        1.120000  1.418044e+10                              101.100000
# 149        1.002457  1.637931e+09                              108.100000
# 120        1.002457  1.330000e+08                              102.470213
# 162        1.220000  2.029000e+12                               98.100000
# 144        1.170000  1.012247e+10                              133.000000
# 122        1.680000  9.090704e+11                              104.200000
# 38         1.002457  1.185729e+09                               99.500000
# 77         0.970000  2.611000e+12                              113.000000
# 27         1.210000  3.012335e+09                              121.400000
#
#      Gross tertiary education enrollment (%)  Infant mortality  \
# 113                                37.963388          2.600000
# 156                                84.800000          2.300000
# 12                                 50.500000          6.100000
# 73                                 37.963388         21.332804
# 104                                31.200000          7.400000
# 106                                54.300000          6.100000
# 13                                 20.600000         25.100000
# 133                                37.963388         21.332804
# 111                                14.100000         25.600000
# 14                                 65.400000         11.300000
# 94                                 26.300000          6.400000
# 109                                40.600000         13.600000
# 149                                42.500000          1.700000
# 120                                37.963388         21.332804
# 162                                94.300000          2.700000
# 144                                 6.700000         27.000000
# 122                                85.000000          3.300000
# 38                                  9.000000         51.300000
# 77                                 28.100000         29.900000
# 27                                  6.100000         41.000000
#
#            Largest city  Life expectancy  Maternal mortality ratio  \
# 113         Monaco City        72.279679                160.392265
# 156                   S        83.100000                  8.000000
# 12                Riffa        77.200000                 14.000000
# 73                    S        72.279679                160.392265
# 104                 Mal        78.600000                 53.000000
# 106          Birkirkara        82.300000                  6.000000
# 13                Dhaka        72.300000                173.000000
# 133                   S        72.279679                160.392265
# 111             Palikir        67.800000                 88.000000
# 14           Bridgetown        79.100000                 27.000000
# 94      Tripoli Lebanon        78.900000                 29.000000
# 109          Port Louis        74.400000                 61.000000
# 149  City of San Marino        85.400000                160.392265
# 120                   S        72.279679                160.392265
# 162               Seoul        82.600000                 11.000000
# 144              Kigali        68.700000                248.000000
# 122           Amsterdam        81.800000                  5.000000
# 38       Moroni Comoros        64.100000                273.000000
# 77             Kurebhar        69.400000                145.000000
# 27            Bujumbura        61.200000                548.000000
#
#      Minimum wage Official language  Out of pocket health expenditure  \
# 113     11.720000            French                          6.100000
# 156      2.194133             Malay                         36.700000
# 12       2.194133            Arabic                         25.100000
# 73       2.194133           Italian                         32.637234
# 104      2.194133            Divehi                         16.400000
# 106      5.070000           Maltese                         37.100000
# 13       0.510000           Bengali                         71.800000
# 133      2.194133            Arabic                         32.637234
# 111      2.194133           English                          2.500000
# 14       3.130000           English                         45.200000
# 94       2.150000            Arabic                         32.100000
# 109      0.380000            French                         50.700000
# 149      2.194133           Italian                         18.300000
# 120      2.194133           English                         32.637234
# 162      6.490000            Korean                         36.800000
# 144      2.194133           Swahili                         26.000000
# 122     10.290000             Dutch                         12.300000
# 38       0.710000            French                         74.800000
# 77       0.300000             Hindi                         65.100000
# 27       2.194133           Kirundi                         19.100000
#
#      Physicians per thousand    Population  \
# 113                  6.56000  3.896400e+04
# 156                  2.29000  5.703569e+06
# 12                   0.93000  1.501635e+06
# 73                   1.83984  8.360000e+02
# 104                  4.56000  5.309530e+05
# 106                  2.86000  5.026530e+05
# 13                   0.58000  1.673108e+08
# 133                  1.83984  3.938116e+07
# 111                  0.18000  1.138150e+05
# 14                   2.48000  2.870250e+05
# 94                   2.10000  6.855713e+06
# 109                  2.53000  1.265711e+06
# 149                  6.11000  3.386000e+04
# 120                  1.83984  1.008400e+04
# 162                  2.36000  5.170910e+07
# 144                  0.13000  1.262695e+07
# 122                  3.61000  1.733285e+07
# 38                   0.27000  8.508860e+05
# 77                   0.86000  1.366418e+09
# 27                   0.10000  1.153058e+07
#
#      Population: Labor force participation (%)  Tax revenue (%)  \
# 113                                  62.738068        16.573964
# 156                                  70.500000        13.100000
# 12                                   73.400000         4.200000
# 73                                   62.738068        16.573964
# 104                                  69.800000        19.500000
# 106                                  56.500000        26.200000
# 13                                   59.000000         8.800000
# 133                                  62.738068        16.573964
# 111                                  62.738068        25.200000
# 14                                   65.200000        27.500000
# 94                                   47.000000        15.300000
# 109                                  58.300000        19.100000
# 149                                  62.738068        18.100000
# 120                                  62.738068        16.573964
# 162                                  63.000000        15.600000
# 144                                  83.700000        14.300000
# 122                                  63.600000        23.000000
# 38                                   43.300000        16.573964
# 77                                   49.300000        11.200000
# 27                                   79.200000        13.600000
#
#      Total tax rate  Unemployment rate  Urban_population   Latitude  \
# 113       40.822404           6.886364      3.896400e+04  43.738418
# 156       21.000000           4.110000      5.703569e+06   1.352083
# 12        13.800000           0.710000      1.467109e+06  26.066700
# 73        40.822404           6.886364      2.230454e+07  41.902916
# 104       30.200000           6.140000      2.136450e+05   3.202778
# 106       44.000000           3.470000      4.759020e+05  35.937496
# 13        33.400000           4.190000      6.098742e+07  23.684994
# 133       40.822404           6.886364      2.230454e+07  31.952162
# 111       60.500000           6.886364      2.596300e+04   7.425554
# 14        35.600000          10.330000      8.943100e+04  13.193887
# 94        32.200000           6.230000      6.084994e+06  33.854721
# 109       22.200000           6.670000      5.159800e+05 -20.348404
# 149       36.200000           6.886364      3.296900e+04  43.942360
# 120       40.822404           6.886364      2.230454e+07  -0.522778
# 162       33.200000           4.150000      4.210672e+07  35.907757
# 144       33.200000           1.030000      2.186104e+06  -1.940278
# 122       41.200000           3.200000      1.592473e+07  52.132633
# 38       219.600000           4.340000      2.481520e+05 -11.645500
# 77        49.700000           5.360000      4.710315e+08  20.593684
# 27        41.200000           1.430000      1.541177e+06  -3.373056
#
#       Longitude
# 113    7.424616
# 156  103.819836
# 12    50.557700
# 73    12.453389
# 104   73.220680
# 106   14.375416
# 13    90.356331
# 133   35.233154
# 111  150.550812
# 14   -59.543198
# 94    35.862285
# 109   57.552152
# 149   12.457777
# 120  166.931503
# 162  127.766922
# 144   29.873888
# 122    5.291266
# 38    43.333300
# 77    78.962880
# 27    29.918886

# %%
plt.figure(figsize=(15,5))

agri = sns.barplot(data=top20_most_agri_countries,x='Country', y='Agricultural Land( %)')
plt.xticks(rotation=45,horizontalalignment='right')
# agri.text(x='',y='',s='Agricultural Land( %)')
plt.show()
# sns.barplot(data=top20_most_agri_countries,x='Agricultural Land(Km2)', y='Country')

# %% [markdown]
# ## Top 20 Least Agricultural Land Countries

# %%
agri_sorted_df = df.sort_values(by='Agricultural Land( %)')
top20_least_agri_countries = agri_sorted_df.head(20)

# %%
plt.figure(figsize=(15,5))

agri = sns.barplot(data=top20_least_agri_countries,x='Country', y='Agricultural Land( %)')
plt.xticks(rotation=45,horizontalalignment='right')

# Add value labels
for p in agri.patches:
    agri.annotate(
        format(p.get_height(), '.1f'),  # no decimals
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center', va='bottom',
        fontsize=9, color='black', xytext=(0, 3),
        textcoords='offset points'
    )
# agri.text(x='',y='',s='Agricultural Land( %)')
plt.show()

# %% [markdown]
# ## Top 10 Most Agricultural Land Countries by Area

# %%
# Reshape to long format
top10_most_agri_countries_in_km2 = top20_most_agri_countries.sort_values(by='Agricultural Land(Km2)', ascending=False).head(10)
df_long = top10_most_agri_countries_in_km2.melt(
    id_vars="Country",
    value_vars=["Agricultural Land(Km2)", "Land Area(Km2)"],
    var_name="Land Type",
    value_name="Area"
)

# Plot grouped barplot
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=df_long,
    x="Country",
    y="Area",
    hue="Land Type",
    palette="dark:#5A9_r"
)



plt.xticks(rotation=45, ha='right')
plt.ylabel("Land Area (sq km)")
plt.title("Agricultural vs Total Land Area per Country")
plt.legend(title="Land Type")
plt.tight_layout()
plt.show()
